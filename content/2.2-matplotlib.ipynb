# %% [markdown]
# # matplotlib

# %% [markdown]
# matplotlib is a library for making plots. We will start with a few simple examples.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## A line plot
#
# The simplest plot is often a line through a set of points.

# %%
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]
plt.plot(x, y)
plt.show()

# %% [markdown]
# We can add labels and a title to make the plot easier to read.

# %%
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("A simple curve")
plt.show()

# %% [markdown]
# ## Other plot types
#
# matplotlib can also make scatter plots and histograms.

# %%
plt.scatter([1, 2, 3, 4], [4, 1, 3, 2])
plt.show()

# %%
values = [1, 1, 2, 2, 2, 3, 4, 4, 5]
plt.hist(values)
plt.show()

# %% [markdown]
# ## Working with figure and axes
#
# A common pattern is to create a figure and axes object, and then draw on the axes.

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("The same curve again")
plt.show()

# %% [markdown]
# **Exercise**
#
# Make a line plot of the points `(0, 0)`, `(1, 1)`, `(2, 8)`, and `(3, 27)`.
#
# Add labels to both axes and give the plot a title.

# %%
# Write your answer here

# %% [markdown]
# ::: {note} Solution (Don't look until you're done)
# :class: dropdown
#
# One possible answer is:
#
# ```python
# x = [0, 1, 2, 3]
# y = [0, 1, 8, 27]
# plt.plot(x, y)
# plt.xlabel("x")
# plt.ylabel("y")
# plt.title("A cubic curve")
# plt.show()
# ```
# :::
